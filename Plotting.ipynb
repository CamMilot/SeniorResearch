# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dm = pd.read_csv("TestData\DIST1m.csv")
dk = pd.read_csv("TestData\DIST100k.csv")
pm = pd.read_csv("TestData\PBRS1m.csv")
pk = pd.read_csv("TestData\PBRS100k.csv")
sm = pd.read_csv("TestData\SMOOTHED1m.csv")
sk = pd.read_csv("TestData\SMOOTHED100k.csv")

# %%
maxes1 = pd.concat([dk['Trial 4'],pk['Trial 1'],sk['Trial 3']],axis=1)
maxes1.columns = ['Dist Max 100k','PBRS Max 100k','Smoothed Max 100k']

# %%
maxes = pd.concat([dm["Trial 3"],pm["Trial 5"],sm["Trial 3"]],axis=1)

# %%
sns.histplot(maxes)
plt.title("Max Count Trials")
plt.ylim(0, 150)
# Out:
# (0.0, 150.0)

# %%
sns.histplot(pm,palette='rocket')
plt.title('PBRS Trials')
plt.ylim(0, 150)
# Out:
# (0.0, 150.0)

# %%
sns.histplot(dm,palette='mako')
plt.title('Distance Trials')
plt.ylim(0, 150)
# Out:
# (0.0, 150.0)

# %%
sns.histplot(sm,palette='cubehelix')
plt.title('Smoothed Trials')
plt.ylim(0, 150)
# Out:
# (0.0, 150.0)

# %%
maxes.columns = ['Dist Max 1m','PBRS Max 1m','Smoothed Max 1m']
sns.lineplot(maxes)
plt.title("Max Count Trials")
# Out:
# Text(0.5, 1.0, 'Max Count Trials')

# %%
sns.lineplot(dm,palette='mako')
plt.xlim(0, 500)
plt.title('Distance Trials')
# Out:
# Text(0.5, 1.0, 'Distance Trials')

# %%
sns.lineplot(pm,palette='rocket')
plt.xlim(0, 500)
plt.title('PBRS Trials')
# Out:
# Text(0.5, 1.0, 'PBRS Trials')

# %%
sns.lineplot(sm,palette='cubehelix')
plt.title('Smoothed Trials')
plt.xlim(0, 500)
# Out:
# (0.0, 500.0)

# %%
sns.histplot(pk,palette='rocket')
plt.title('PBRS Trials')
plt.ylim(0,50)
# Out:
# (0.0, 50.0)

# %%
sns.histplot(dk,palette='mako')
plt.title('Dist Trials')
plt.ylim(0,50)
# Out:
# (0.0, 50.0)

# %%
sns.histplot(sk,palette='cubehelix')
plt.title('Smoothed Trials')
plt.ylim(0,50)
# Out:
# (0.0, 50.0)

# %%
sns.histplot(maxes1)
plt.title('Max Trials')
plt.ylim(0,50)
# Out:
# (0.0, 50.0)
